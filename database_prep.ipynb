# %%
# !pip install opencv-python
#!pip install keras
# !pip install imutils
#!pip install tensorflow
# Out:
# ...
#   Using cached opencv_python-4.7.0.72-cp37-abi3-win_amd64.whl (38.2 MB)
# ...
#   Using cached imutils-0.5.4-py3-none-any.whl
# ...

# %%
# !pip install numpy
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#      - -------------------------------------- 0.3/10.9 MB 9.9 MB/s eta 0:00:02
#      - -------------------------------------- 0.4/10.9 MB 4.6 MB/s eta 0:00:03
#      - -------------------------------------- 0.4/10.9 MB 3.4 MB/s eta 0:00:04
#      - -------------------------------------- 0.5/10.9 MB 2.8 MB/s eta 0:00:04
#      - -------------------------------------- 0.5/10.9 MB 2.4 MB/s eta 0:00:05
#      -- ------------------------------------- 0.6/10.9 MB 2.3 MB/s eta 0:00:05
#      -- ------------------------------------- 0.7/10.9 MB 2.1 MB/s eta 0:00:05
#      -- ------------------------------------- 0.7/10.9 MB 2.0 MB/s eta 0:00:06
#      -- ------------------------------------- 0.8/10.9 MB 1.9 MB/s eta 0:00:06
#      --- ------------------------------------ 0.8/10.9 MB 1.8 MB/s eta 0:00:06
#      --- ------------------------------------ 0.9/10.9 MB 1.8 MB/s eta 0:00:06
# ...

# %%
# !pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#      - -------------------------------------- 0.3/8.4 MB 9.9 MB/s eta 0:00:01
#      - -------------------------------------- 0.4/8.4 MB 4.9 MB/s eta 0:00:02
#      -- ------------------------------------- 0.5/8.4 MB 3.5 MB/s eta 0:00:03
#      -- ------------------------------------- 0.5/8.4 MB 2.8 MB/s eta 0:00:03
#      -- ------------------------------------- 0.5/8.4 MB 2.4 MB/s eta 0:00:04
#      -- ------------------------------------- 0.6/8.4 MB 2.3 MB/s eta 0:00:04
#      --- ------------------------------------ 0.7/8.4 MB 2.2 MB/s eta 0:00:04
#      --- ------------------------------------ 0.7/8.4 MB 2.1 MB/s eta 0:00:04
#      --- ------------------------------------ 0.8/8.4 MB 1.9 MB/s eta 0:00:04
#      --- ------------------------------------ 0.8/8.4 MB 1.8 MB/s eta 0:00:05
#      ---- ----------------------------------- 0.9/8.4 MB 1.8 MB/s eta 0:00:05
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#      - -------------------------------------- 0.2/7.6 MB 5.0 MB/s eta 0:00:02
#      - -------------------------------------- 0.3/7.6 MB 4.3 MB/s eta 0:00:02
#      -- ------------------------------------- 0.5/7.6 MB 3.1 MB/s eta 0:00:03
#      -- ------------------------------------- 0.5/7.6 MB 2.8 MB/s eta 0:00:03
#      -- ------------------------------------- 0.6/7.6 MB 2.5 MB/s eta 0:00:03
#      --- ------------------------------------ 0.6/7.6 MB 2.2 MB/s eta 0:00:04
#      --- ------------------------------------ 0.7/7.6 MB 2.1 MB/s eta 0:00:04
#      --- ------------------------------------ 0.7/7.6 MB 2.0 MB/s eta 0:00:04
#      ---- ----------------------------------- 0.8/7.6 MB 1.9 MB/s eta 0:00:04
#      ---- ----------------------------------- 0.8/7.6 MB 1.8 MB/s eta 0:00:04
#      ---- ----------------------------------- 0.9/7.6 MB 1.8 MB/s eta 0:00:04
# ...

# %%
 # !pip install matplotlib --user

# %%
# !pip install scikit-image
# Out:
# ...
#   Using cached scikit_image-0.20.0-cp39-cp39-win_amd64.whl (23.9 MB)
# ...
#   Using cached lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# ...
#   Using cached imageio-2.27.0-py3-none-any.whl (3.4 MB)
# ...
#   Using cached PyWavelets-1.4.1-cp39-cp39-win_amd64.whl (4.2 MB)
# ...
#   Using cached networkx-3.0-py3-none-any.whl (2.0 MB)
# ...

# %%
from imutils import paths
import os
import numpy as np
import pandas as pd
import random 
from sklearn.model_selection import train_test_split

# %%
import cv2
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy import ndimage as ndi
from skimage import morphology
import time

# %%
import tensorflow as tf
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import regularizers

# %%
import tensorflow as tf
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn import metrics

# %% [markdown]
# #Creating temporary data folder for training

# %%
# !mkdir D:\kaggle_prepared_dataset\tmp\prepared_data\benign

# %%
# !mkdir D:\kaggle_prepared_dataset\tmp\prepared_data\PreB
# !mkdir D:\kaggle_prepared_dataset\tmp\prepared_data\ProB
# !mkdir D:\kaggle_prepared_dataset\tmp\prepared_data\EarlyPreB

# %% [markdown]
# Creating temporary test folder

# %%
# !mkdir D:\kaggle_prepared_dataset\tmp\prepared_test\benign
# !mkdir D:\kaggle_prepared_dataset\tmp\prepared_test\PreB
# !mkdir D:\kaggle_prepared_dataset\tmp\prepared_test\ProB
# !mkdir D:\kaggle_prepared_dataset\tmp\prepared_test\EarlyPreB

# %% [markdown]
# splitting dataset into Train_list and Test_list

# %%
data_dir='D:\kaggle_ml_dataset\Blood cell Cancer [ALL]'
data_list = sorted(list(paths.list_images(data_dir)))

random.seed(88)
random.shuffle(data_list)

train_list, test_list = train_test_split(data_list, train_size=0.80, shuffle=True, random_state=88)

print('number of testing list -:',len(test_list))
print('number of training list-:',len(train_list))
# Out:
# number of testing list -: 832
# number of training list-: 3324

# %%
print('Number of samples in dataset:',len(list(paths.list_images("D:\kaggle_ml_dataset\Blood cell Cancer [ALL]"))),'\n')

print('Number of samples in each class:','\n')
print("#1 Benign ---------------:", len(list(paths.list_images("D:\kaggle_ml_dataset\Blood cell Cancer [ALL]\Benign"))))
print("#2 Malignant[PreB] :", len(list(paths.list_images("D:\kaggle_ml_dataset\Blood cell Cancer [ALL]\[Malignant] Pre-B"))))
print("#3 Malignant[Early PreB] ------:", len(list(paths.list_images("D:\kaggle_ml_dataset\Blood cell Cancer [ALL]\[Malignant] early Pre-B"))))
print("#4 Malignant[ProB] ------:", len(list(paths.list_images("D:\kaggle_ml_dataset\Blood cell Cancer [ALL]\[Malignant] Pro-B"))))
# Out:
# Number of samples in dataset: 3242
#
# Number of samples in each class:
#
# #1 Benign ---------------: 512
# #2 Malignant[PreB] : 955
# #3 Malignant[Early PreB] ------: 979
# #4 Malignant[ProB] ------: 796

# %%
test_list
# Out:
# ['D:\\kaggle_ml_dataset\\Blood cell Cancer [ALL]\\[Malignant] Pre-B\\Snap_819.jpg',
#  'D:\\kaggle_ml_dataset\\Blood cell Cancer [ALL]\\[Malignant] early Pre-B\\Snap_136 - Copy.jpg',
#  'D:\\kaggle_ml_dataset\\Blood cell Cancer [ALL]\\[Malignant] early Pre-B\\Snap_233 - Copy.jpg',
#  'D:\\kaggle_ml_dataset\\Blood cell Cancer [ALL]\\[Malignant] Pre-B\\Snap_146.jpg',
#  'D:\\kaggle_ml_dataset\\Blood cell Cancer [ALL]\\[Malignant] Pre-B\\Snap_259.jpg',
#  'D:\\kaggle_ml_dataset\\Blood cell Cancer [ALL]\\[Malignant] early Pre-B\\Snap_235 - Copy.jpg',
#  'D:\\kaggle_ml_dataset\\Blood cell Cancer [ALL]\\[Malignant] Pro-B\\Snap_161.jpg',
#  'D:\\kaggle_ml_dataset\\Blood cell Cancer [ALL]\\[Malignant] Pre-B\\Snap_289.jpg',
#  'D:\\kaggle_ml_dataset\\Blood cell Cancer [ALL]\\Benign\\Snap_072 (3).jpg',
#  'D:\\kaggle_ml_dataset\\Blood cell Cancer [ALL]\\[Malignant] Pre-B\\Snap_300.jpg',
#  'D:\\kaggle_ml_dataset\\Blood cell Cancer [ALL]\\[Malignant] early Pre-B\\Snp_147 (145).jpg',
# ...

# %% [markdown]
# Now storing images to new directories while relabeling images and bifurcating them into classified types.
# Using os and openCV computer vision library to read images, resize them and store them in dedicated new directories

# %%
p=0
tic = time.perf_counter()
b = 'default_filename.png'
for img in train_list[:]:

    
    i= cv2.imread(img)    
    i= cv2.resize(i,(224,224))
    lable= img.split(os.path.sep)[3]
   
    
    if(lable=="no_cancer"):
         print(lable)
         b= ('D:\\kaggle_prepared_dataset\\tmp\\prepared_data\\no_cancer\\'+lable+str(p)+'.png') 
    
    p+=1
    cv2.imwrite(b,i)
# Out:
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# no_cancer
# ...

# %%
p=0

tic = time.perf_counter()
for img in test_list[:]:
    i= cv2.imread(img)    
    i= cv2.resize(i,(224,224))
    lable= img.split(os.path.sep)[3]
    print(lable)
    i= cv2.cvtColor(i, cv2.COLOR_BGR2RGB)
    i_lab = cv2.cvtColor(i, cv2.COLOR_RGB2LAB)        #RGB -> LAB
    l,a,b = cv2.split(i_lab)                         
    i2 = a.reshape(a.shape[0]*a.shape[1],1)
    km= KMeans(n_clusters=7, random_state=0).fit(i2)  #Clustring
    p2s= km.cluster_centers_[km.labels_]
    ic= p2s.reshape(a.shape[0],a.shape[1])
    ic = ic.astype(np.uint8)
    r,t = cv2.threshold(ic,141,255 ,cv2.THRESH_BINARY) #Binary Thresholding
    fh = ndi.binary_fill_holes(t)                      #fill holes
    m1 = morphology.remove_small_objects(fh, 200)
    m2 = morphology.remove_small_holes(m1,250)
    m2 = m2.astype(np.uint8)  
    out = cv2.bitwise_and(i, i, mask=m2) 
    
   
    
    if (lable=="Benign"):
        b= ('D:\\kaggle_prepared_dataset\\tmp\\prepared_test\\benign\\'+lable+str(p)+'.png') 
    if (lable=="[Malignant] Pre-B"):
        b= ('D:\\kaggle_prepared_dataset\\tmp\\prepared_test\\PreB\\'+lable+str(p)+'.png')  
    if (lable=="[Malignant] Pro-B"):
        b= ('D:\\kaggle_prepared_dataset\\tmp\\prepared_test\\ProB\\'+lable+str(p)+'.png') 
    if (lable=="[Malignant] early Pre-B"):
        b= ('D:\\kaggle_prepared_dataset\\tmp\\prepared_test\\EarlyPreB\\'+lable+str(p)+'.png')
    p+=1
    out= cv2.cvtColor(out, cv2.COLOR_RGB2BGR)
    cv2.imwrite(b,out)
    
toc2 = time.perf_counter()
print(f"649 samples processed in { ((toc2 - tic)/60) } minutes")
# Out:
# [Malignant] Pre-B
# [Malignant] early Pre-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] Pre-B
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] Pre-B
# Benign
# [Malignant] Pre-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] Pro-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] Pre-B
# [Malignant] Pre-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] early Pre-B
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] Pre-B
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] Pre-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] Pre-B
# [Malignant] Pro-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] early Pre-B
# ...

# %% [markdown]
# storing in prepared_data to be given for training

# %%
p=0
b = 'default_filename.png'
for img in train_list[:]:
    
    i= cv2.imread(img)    
    i= cv2.resize(i,(224,224))
    lable= img.split(os.path.sep)[3]
    print(lable)
    if (lable=="Benign"):
        b= ('D:\\kaggle_prepared_dataset\\tmp\\\prepared_data\\benign\\'+lable+str(p)+'.png') 
    if (lable=="[Malignant] Pre-B"):
        b= ('D:\\kaggle_prepared_dataset\\tmp\\\prepared_data\\PreB\\'+lable+str(p)+'.png')  
    if (lable=="[Malignant] Pro-B"):
        b= ('D:\\kaggle_prepared_dataset\\tmp\\\prepared_data\\ProB\\'+lable+str(p)+'.png') 
    if (lable=="[Malignant] early Pre-B"):
        b= ('D:\\kaggle_prepared_dataset\\tmp\\\prepared_data\\EarlyPreB\\'+lable+str(p)+'.png')
    p+=1
    cv2.imwrite(b,i)
# Out:
# Benign
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] Pre-B
# [Malignant] Pro-B
# [Malignant] Pre-B
# Benign
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] Pro-B
# [Malignant] Pre-B
# [Malignant] early Pre-B
# [Malignant] early Pre-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] Pre-B
# [Malignant] Pro-B
# Benign
# Benign
# [Malignant] Pro-B
# [Malignant] Pro-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] Pro-B
# Benign
# [Malignant] Pre-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] early Pre-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] Pro-B
# [Malignant] Pre-B
# [Malignant] Pro-B
# [Malignant] Pre-B
# [Malignant] early Pre-B
# ...

# %% [markdown]
# We used the cv2 module from OpenCV to read and manipulate images.
# The train_list variable is a list of file paths to images that the code will process. Iterating over each image in the list.
# Each image is loaded and resized to 224x224 pixels using cv2.resize().
# The image is converted from BGR to RGB color space using cv2.cvtColor().
# The image is converted from RGB to LAB color space using cv2.cvtColor().
# The a channel of the LAB image is extracted and flattened into a 1D array.
# KMeans clustering algorithm is applied to the 1D array with n_clusters=7.
# The cluster centers and labels are used to create a new image with pixel values corresponding to the cluster centers.
# Binary thresholding is applied to the new image to create a binary mask.
# Morphological operations are applied to the mask to fill holes and remove small objects and small holes.
# The original RGB image is masked with the final mask to create a new image with only the relevant objects in the image.
# Lastly it saves the output image to a file path depending on the label of the original image.

# %% [markdown]
# K-means clustering is an unsupervised machine learning algorithm that partitions a given dataset into K distinct clusters, where K is a predetermined number. The algorithm starts by randomly assigning K initial centroids, which are representative points for each cluster. Then, it iteratively assigns each data point to the closest centroid, and updates the centroid of each cluster based on the newly assigned data points. This process continues until the centroids no longer change or a maximum number of iterations is reached.

# %%
p=0

tic = time.perf_counter()
for img in train_list[:]:
    i= cv2.imread(img)    
    i= cv2.resize(i,(224,224))
    lable= img.split(os.path.sep)[3]
    print(lable)
    i= cv2.cvtColor(i, cv2.COLOR_BGR2RGB)
    i_lab = cv2.cvtColor(i, cv2.COLOR_RGB2LAB)        #RGB -> LAB
    l,a,b = cv2.split(i_lab)                         
    i2 = a.reshape(a.shape[0]*a.shape[1],1)
    km= KMeans(n_clusters=7, random_state=0).fit(i2)  #Clustring
    p2s= km.cluster_centers_[km.labels_]
    ic= p2s.reshape(a.shape[0],a.shape[1])
    ic = ic.astype(np.uint8)
    r,t = cv2.threshold(ic,141,255 ,cv2.THRESH_BINARY) #Binary Thresholding
    fh = ndi.binary_fill_holes(t)                      #fill holes
    m1 = morphology.remove_small_objects(fh, 200)
    m2 = morphology.remove_small_holes(m1,250)
    m2 = m2.astype(np.uint8)  
    out = cv2.bitwise_and(i, i, mask=m2)
    
    if (lable=="Benign"):
        b= ('D:\\kaggle_prepared_dataset\\tmp\\\prepared_data\\benign\\'+lable+str(p)+'.png') 
    if (lable=="[Malignant] Pre-B"):
        b= ('D:\\kaggle_prepared_dataset\\tmp\\\prepared_data\\PreB\\'+lable+str(p)+'.png')  
    if (lable=="[Malignant] Pro-B"):
        b= ('D:\\kaggle_prepared_dataset\\tmp\\\prepared_data\\ProB\\'+lable+str(p)+'.png') 
    if (lable=="[Malignant] early Pre-B"):
        b= ('D:\\kaggle_prepared_dataset\\tmp\\\prepared_data\\EarlyPreB\\'+lable+str(p)+'.png')
        
    p+=1
    out= cv2.cvtColor(out, cv2.COLOR_RGB2BGR)
    cv2.imwrite(b,out)
    
toc2 = time.perf_counter()
print(f"2593 samples processed in { ((toc2 - tic)/60) } minutes")
# Out:
# Benign
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] Pre-B
# [Malignant] Pro-B
# [Malignant] Pre-B
# Benign
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] Pro-B
# [Malignant] Pre-B
# [Malignant] early Pre-B
# [Malignant] early Pre-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] Pre-B
# [Malignant] Pro-B
# Benign
# Benign
# [Malignant] Pro-B
# [Malignant] Pro-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] Pro-B
# Benign
# [Malignant] Pre-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] early Pre-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] Pre-B
# [Malignant] Pro-B
# [Malignant] early Pre-B
# [Malignant] Pro-B
# [Malignant] Pro-B
# [Malignant] Pre-B
# [Malignant] Pro-B
# [Malignant] Pre-B
# [Malignant] early Pre-B
# ...

# %% [markdown]
# Displaying some segmented images using matplotlib subplots

# %%
n= 3

o_img=[]
a_img=[]
c_img=[]
b_img=[]
m_img=[]
out_img=[]

random.seed(865)
random.shuffle(data_list)

for img in data_list[:n]:
    i= cv2.imread(img)    
    i= cv2.cvtColor(i, cv2.COLOR_BGR2RGB)
    i= cv2.resize(i,(224,224))
    o_img.append(i)
    i_lab = cv2.cvtColor(i, cv2.COLOR_RGB2LAB)
    l,a,b = cv2.split(i_lab)
    a_img.append(a)
    i2 = a.reshape(a.shape[0]*a.shape[1],1)
    km= KMeans(n_clusters=7, random_state=0).fit(i2)
    p2s= km.cluster_centers_[km.labels_]
    ic= p2s.reshape(a.shape[0],a.shape[1])
    ic = ic.astype(np.uint8)
    c_img.append(ic)
    r,t = cv2.threshold(ic,141,255 ,cv2.THRESH_BINARY)
    b_img.append(t)    
    fh = ndi.binary_fill_holes(t)   
    m1 = morphology.remove_small_objects(fh, 200)
    m2 = morphology.remove_small_holes(m1,250)
    #m2 = ndi.binary_fill_holes(m2)  
    #m1 = m1.astype(np.uint8)
    #m1_imgs.append(m1)
    m2 = m2.astype(np.uint8)  
    m_img.append(m2)
    out = cv2.bitwise_and(i, i, mask=m2)
    out_img.append(out)
    
for j in range(n):    
    for t in range(1):
        #print('=>',j+1,':')
        plt.subplot(2,3,1+t),plt.imshow(o_img[j])
        plt.title('a'),plt.xticks([]),plt.yticks([])
        plt.subplot(2,3,2+t),plt.imshow(a_img[j],'gray')
        plt.title('b'),plt.xticks([]),plt.yticks([])
        plt.subplot(2,3,3+t),plt.imshow(c_img[j],'gray')
        plt.title('c'),plt.xticks([]),plt.yticks([])
        plt.subplot(2,3,4+t),plt.imshow(b_img[j],'gray')
        plt.title('d'),plt.xticks([]),plt.yticks([])
        plt.subplot(2,3,5+t),plt.imshow(m_img[j],'gray')
        plt.title('e'),plt.xticks([]),plt.yticks([])
        plt.subplot(2,3,6+t),plt.imshow(out_img[j])
        plt.title('f'),plt.xticks([]),plt.yticks([])
    plt.show()

# %% [markdown]
# creating a training dataframe for a machine learning model

# %% [markdown]
# creating a test dataframe for a machine learning model

# %%
prepared_data_path = 'D:\\kaggle_prepared_dataset\\tmp\\prepared_test\\'
prepared_data_list_filenames = (sorted(list(paths.list_images(prepared_data_path))))
random.shuffle(prepared_data_list_filenames)
prepared_data_list_labels = []

for line in prepared_data_list_filenames:
    prepared_data_list_labels.append(line.split(os.path.sep)[4])

I_series = pd.Series(prepared_data_list_filenames, name='filenames')
L_series = pd.Series(prepared_data_list_labels, name='labels')
test_df = pd.concat( [I_series, L_series], axis=1) 

print('-- test Datafarame --')
print(test_df.head())
#print number of each class:        
a=test_df['labels'].value_counts()
a
# Out:
# -- test Datafarame --
#                                            filenames     labels
# 0  D:\kaggle_prepared_dataset\tmp\prepared_test\E...  EarlyPreB
# 1  D:\kaggle_prepared_dataset\tmp\prepared_test\n...  no cancer
# 2  D:\kaggle_prepared_dataset\tmp\prepared_test\P...       PreB
# 3  D:\kaggle_prepared_dataset\tmp\prepared_test\P...       ProB
# 4  D:\kaggle_prepared_dataset\tmp\prepared_test\a...        all
# no cancer    216
# EarlyPreB    205
# PreB         189
# all2         161
# ProB         158
# benign        97
# all           83
# all2_test     47
# all_test      25
# Name: labels, dtype: int64

# %%
prepared_data_path = 'D:\\kaggle_prepared_dataset\\tmp\\prepared_data\\'
prepared_data_list_filenames = (sorted(list(paths.list_images(prepared_data_path))))
random.shuffle(prepared_data_list_filenames)
prepared_data_list_labels = []

for line in prepared_data_list_filenames:
    prepared_data_list_labels.append(line.split(os.path.sep)[4])

I_series = pd.Series(prepared_data_list_filenames, name='filenames')
L_series = pd.Series(prepared_data_list_labels, name='labels')
df = pd.concat( [I_series, L_series], axis=1) 

print('-- train/valid Datafarame --')

print(df.head())
#print number of each class:        
a=df['labels'].value_counts()
a
# Out:
# -- train/valid Datafarame --
#                                            filenames     labels
# 0  D:\kaggle_prepared_dataset\tmp\prepared_data\E...  EarlyPreB
# 1  D:\kaggle_prepared_dataset\tmp\prepared_data\n...  no_cancer
# 2  D:\kaggle_prepared_dataset\tmp\prepared_data\E...  EarlyPreB
# 3  D:\kaggle_prepared_dataset\tmp\prepared_data\E...  EarlyPreB
# 4  D:\kaggle_prepared_dataset\tmp\prepared_data\P...       ProB
# no_cancer    914
# EarlyPreB    774
# PreB         766
# ProB         638
# benign       415
# Name: labels, dtype: int64

# %%
'''prepared_data_path = 'D:\\kaggle_prepared_dataset\\tmp\\prepared_test\\'
prepared_data_list_filenames = (sorted(list(paths.list_images(prepared_data_path))))
random.shuffle(prepared_data_list_filenames)
prepared_data_list_labels = []


for line in prepared_data_list_filenames:
    prepared_data_list_labels.append(line.split(os.path.sep)[4])

I_series = pd.Series(prepared_data_list_filenames, name='filenames')
L_series = pd.Series(prepared_data_list_labels, name='labels')
df = pd.concat( [I_series, L_series], axis=1) 

print('-- train/valid Datafarame --')

print(df.head())
#print number of each class:        
a=df['labels'].value_counts()
a
# Out:
# -- train/valid Datafarame --
#                                            filenames  labels
# 0  D:\kaggle_prepared_dataset\tmp\prepared_test\P...    ProB
# 1  D:\kaggle_prepared_dataset\tmp\prepared_test\b...  benign
# 2  D:\kaggle_prepared_dataset\tmp\prepared_test\b...  benign
# 3  D:\kaggle_prepared_dataset\tmp\prepared_test\P...    PreB
# 4  D:\kaggle_prepared_dataset\tmp\prepared_test\b...  benign
# EarlyPreB    205
# PreB         189
# ProB         158
# benign        97
# Name: labels, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
plt.figure(figsize=(10,8))
sns.barplot(x= ['Benign','PreB','ProB','EarlyPreB','no cancer'], y= [a[4],a[2],a[3],a[1],a[0]])
plt.title('Number of All the Data', fontsize=14)
plt.xlabel('Case type', fontsize=12)
plt.ylabel('Count', fontsize=12)
#plt.xticks(range(len(df.index)), ['a', 'b'])
plt.show()

# %% [markdown]
# Splitting dataframe for training and validation parts:

# %%
SPLIT= 0.80

TRAIN_DF, VALID_DF = train_test_split(df, train_size=SPLIT, shuffle=True, random_state=88)

print('Train samples: ', len(TRAIN_DF))
print('Valid samples: ', len(VALID_DF))
print('Test samples : ', len(test_df))
# Out:
# Train samples:  2805
# Valid samples:  702
# Test samples :  1181

# %%
test_df['labels'].value_counts()
# Out:
# no cancer    216
# EarlyPreB    205
# PreB         189
# ProB         158
# benign        97
# Name: labels, dtype: int64

# %%
df['labels'].value_counts()
# Out:
# no_cancer    914
# EarlyPreB    774
# PreB         766
# ProB         638
# benign       415
# Name: labels, dtype: int64

# %% [markdown]
# setting up image data generators for a machine learning model that will be trained on image data using keras ImageDataGenerator.specifying some values for constants like batch size. The first generator flips images vertically and horizontally for augmentation while the second generator only rescales the images.

# %%
BATCH_SIZE= 32
IMG_SHAPE= (224, 224, 3)
IMG_SIZE= (224, 224)

gen = ImageDataGenerator(rescale=1./255, 
                         vertical_flip=True,
                         horizontal_flip=True)
                         #rotation_range=10)

gen2 = ImageDataGenerator(rescale=1./255)

train_gen = gen.flow_from_dataframe(TRAIN_DF,
                                    x_col= 'filenames',
                                    y_col= 'labels',
                                    target_size= IMG_SIZE,
                                    class_mode= 'categorical',
                                    color_mode= 'rgb',
                                    shuffle= True,
                                    batch_size= BATCH_SIZE,
                                    seed=88
)

valid_gen= gen2.flow_from_dataframe(VALID_DF,
                                    x_col= 'filenames',
                                    y_col= 'labels',
                                    target_size= IMG_SIZE,
                                    class_mode= 'categorical',
                                    color_mode= 'rgb',
                                    shuffle= True,
                                    batch_size= BATCH_SIZE,
                                    seed=88
)
test_gen= gen2.flow_from_dataframe(test_df,
                                   x_col= 'filenames',
                                   y_col= 'labels',
                                   target_size= IMG_SIZE,
                                   class_mode= 'categorical',
                                   color_mode= 'rgb',
                                   shuffle= True,
                                   batch_size= 325,
                                   seed=88
)

train_num = train_gen.samples
valid_num = valid_gen.samples


STEPS= int( len(train_gen.labels)/BATCH_SIZE)
print(STEPS)
# Out:
# Found 2805 validated image filenames belonging to 5 classes.
# Found 702 validated image filenames belonging to 5 classes.
# Found 1181 validated image filenames belonging to 9 classes.
# 87

# %%
import PIL

# %%
# !pip uninstall Pillow
# !pip install Pillow

# %% [markdown]
# printing some images from training image data generator

# %%
genn=train_gen
class_dictionary= genn.class_indices
class_names = list(class_dictionary.keys())
images, labels = next(genn) #get sample batch from the generator
plt.figure(figsize=(20,20))
length = len(labels)

if length<25:
    r=length
else:
    r=25

for i in range(r):
    plt.subplot(5, 5, i+1)
    image= (images[i])
    #image= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    index=np.argmax(labels[i])
    class_name= class_names[index]
    plt.title(class_name, color='blue', fontsize=16)
    plt.axis('off')
plt.show()

# %%
from tensorflow.keras.models import Sequential
AlexNet_model=Sequential()
    

AlexNet_model.add(tf.keras.layers.Conv2D(96, kernel_size=(11,11), strides= 4,
                        padding= 'valid', activation= 'relu',
                        input_shape=(224,224,3),
                        kernel_initializer= 'he_normal'))
AlexNet_model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides= (2,2),
                              padding= 'valid', data_format= None))

AlexNet_model.add(tf.keras.layers.Conv2D(256, kernel_size=(5,5), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'))
AlexNet_model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides= (2,2),
                              padding= 'valid', data_format= None)) 

AlexNet_model.add(tf.keras.layers.Conv2D(384, kernel_size=(3,3), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'))
AlexNet_model.add(tf.keras.layers.Conv2D(384, kernel_size=(3,3), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'))

AlexNet_model.add(tf.keras.layers.Conv2D(256, kernel_size=(3,3), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'))

AlexNet_model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides= (2,2),
                              padding= 'valid', data_format= None))

AlexNet_model.add(tf.keras.layers.Flatten())
AlexNet_model.add(tf.keras.layers.Dense(4096, activation= 'relu'))
AlexNet_model.add(tf.keras.layers.Dense(4096, activation= 'relu'))
AlexNet_model.add(tf.keras.layers.Dense(1000, activation= 'relu'))
AlexNet_model.add(tf.keras.layers.Dense(5, activation= 'softmax'))

AlexNet_model.compile(optimizer= tf.keras.optimizers.Adam(0.001),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

# %%
num_classes = 5
#model = AlexNet(tf.keras.models.Sequential,(224, 224, 3), num_classes)
# training parameters
EPOCHS = 30
BATCH_SIZE = 32
image_height = 224
image_width = 224
train_dir = "D:\\kaggle_prepared_dataset\\tmp\\prepared_data\\"
valid_dir = "D:\\kaggle_prepared_dataset\\tmp\\prepared_test\\"
model_dir = "D:\\kaggle_prepared_dataset\\alexmodel\\"

# %%
os.mkdir('D:\\kaggle_prepared_dataset\\tmp\\logs')
os.mkdir('D:\\kaggle_prepared_dataset\\tmp\\logs\\fit')

# %%
import datetime

log_dir="./logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)
callback_list = [tensorboard_callback]

# start training
AlexNet_model.fit(train_gen,
                    epochs=EPOCHS,
                    steps_per_epoch=train_num // BATCH_SIZE,
                    validation_data=valid_gen,
                    validation_steps=valid_num // BATCH_SIZE,
                    callbacks=callback_list,
                    verbose=0)
AlexNet_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_10 (Conv2D)          (None, 54, 54, 96)        34944
#
#  max_pooling2d_6 (MaxPooling  (None, 26, 26, 96)       0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 26, 26, 256)       614656
#
#  max_pooling2d_7 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 12, 12, 384)       885120
#
#  conv2d_13 (Conv2D)          (None, 12, 12, 384)       1327488
#
#  conv2d_14 (Conv2D)          (None, 12, 12, 256)       884992
#
#  max_pooling2d_8 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 6400)              0
#
#  dense_8 (Dense)             (None, 4096)              26218496
#
#  dense_9 (Dense)             (None, 4096)              16781312
#
#  dense_10 (Dense)            (None, 1000)              4097000
#
# ...

# %%
# %tensorboard --logdir logs/fit
# Out:
#       <iframe id="tensorboard-frame-59ba57acaa1af34f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-59ba57acaa1af34f");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %load_ext tensorboard

# %%
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense
from keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D, AveragePooling2D
#tf.random.set_seed(42)
base_model= tf.keras.applications.mobilenet_v2.MobileNetV2(include_top=False,weights='imagenet',input_shape=(224,224,3))
#tf.keras.applications.MobileNetV3Small

x = base_model.output

x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x) 
#x = Dense(128, activation= 'relu',kernel_initializer='he_uniform')(x)
#x = BatchNormalization()(x)
#x = Dropout(0.3)(x)
predictions = tf.keras.layers.Dense(5, activation= "softmax")(x) 
model = Model(inputs=base_model.input, outputs=predictions)

# %% [markdown]
# setting parameters for model

# %%
initial_learning_rate = 0.0001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=40,
    decay_rate=0.96,
    staircase=False)


model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule, beta_1=0.9, beta_2=0.999, epsilon=1e-08), #optimizer=Adam(learning_rate=0.00001,decay = 10e-5),
              metrics=['accuracy'])
             # option = run_opts)

# %% [markdown]
# model training

# %%
history =         model.fit(x=train_gen,
                            epochs=30,
                            validation_data=valid_gen,
                            steps_per_epoch=None,
                            workers=2
                   )
# Out:
# Epoch 1/30
# 88/88 [==============================] - 35s 322ms/step - loss: 0.3493 - accuracy: 0.8756 - val_loss: 1.6308 - val_accuracy: 0.3248
# Epoch 2/30
# 88/88 [==============================] - 26s 294ms/step - loss: 0.1082 - accuracy: 0.9608 - val_loss: 1.5788 - val_accuracy: 0.4217
# Epoch 3/30
# 88/88 [==============================] - 26s 295ms/step - loss: 0.0819 - accuracy: 0.9722 - val_loss: 1.7040 - val_accuracy: 0.5057
# Epoch 4/30
# 88/88 [==============================] - 26s 296ms/step - loss: 0.0581 - accuracy: 0.9811 - val_loss: 2.2178 - val_accuracy: 0.3732
# Epoch 5/30
# 88/88 [==============================] - 26s 296ms/step - loss: 0.0429 - accuracy: 0.9847 - val_loss: 2.0491 - val_accuracy: 0.4145
# Epoch 6/30
# 88/88 [==============================] - 26s 298ms/step - loss: 0.0401 - accuracy: 0.9875 - val_loss: 1.2725 - val_accuracy: 0.5456
# Epoch 7/30
# ...

# %%
class_names
# Out:
# ['EarlyPreB', 'PreB', 'ProB', 'benign', 'no_cancer']

# %%
from sklearn.metrics import confusion_matrix


for X_batch, y_batch in test_gen:
    y_test = y_batch
    X_test = X_batch
    break
    
print('test label shape',y_test.shape)
print('test image shape',X_test.shape)
print('Evaluate on test-data:')
model.evaluate(X_test,y_test)

pred = model.predict(X_test)

bin_predict = np.argmax(pred,axis=1)
y_test = np.argmax(y_test,axis=1)


#Confusion matrix:
matrix = confusion_matrix(y_test, bin_predict)
print('Confusion Matrix:\n',matrix)
# Out:
# test label shape (325, 9)
# test image shape (325, 224, 224, 3)
# Evaluate on test-data:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2976/3995984651.py in <module>
#      10 print('test image shape',X_test.shape)
#      11 print('Evaluate on test-data:')
# ---> 12 model.evaluate(X_test,y_test)
#      13
#      14 pred = model.predict(X_test)
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
# ...

# %%
save_options1 = tf.saved_model.SaveOptions(save_debug_info=True)

# %%
tf.saved_model.save(model, 'D:\\kaggle_prepared_dataset\\working_model2\\', options=save_options1)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: D:\kaggle_prepared_dataset\working_model2\assets
# INFO:tensorflow:Assets written to: D:\kaggle_prepared_dataset\working_model2\assets

# %%
model.save('D:\\kaggle_prepared_dataset\\working_model3\\')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: D:\kaggle_prepared_dataset\working_model3\assets
# INFO:tensorflow:Assets written to: D:\kaggle_prepared_dataset\working_model3\assets

# %%
np.__version__
tf.__version__
# Out:
# '2.10.0'

# %%
# Create a function to import an image and resize it to be able to be used with our model
def load_and_prep_image(filename, img_shape=224):
  """
  Reads an image from filename, turns it into a tensor
  and reshapes it to (img_shape, img_shape, colour_channel).
  """
  # Read in target file (an image)
  img = tf.io.read_file(filename)

  # Decode the read file into a tensor & ensure 3 colour channels 
  # (our model is trained on images with 3 colour channels and sometimes images have 4 colour channels)
  img = tf.image.decode_image(img, channels=3)

  # Resize the image (to the same size our model was trained on)
  img = tf.image.resize(img, size = [img_shape, img_shape])

  # Rescale the image (get all values between 0 and 1)
  img = img/255.
  return img

# %%
'''def pred_and_plot(model, filename, class_names):
  """
  Imports an image located at filename, makes a prediction on it with
  a trained model and plots the image with the predicted class as the title.
  """
  # Import the target image and preprocess it
  img = load_and_prep_image(filename)

  # Make a prediction
  pred = model.predict(tf.expand_dims(img, axis=1))
  print(len(pred[0]))
  #cred=tf.constant(pred)
  #cred1=cred.numpy()
  #print(cred1)  
  if len(pred[0])>1:
       # pred_class_idx = int(tf.argmax(pred[0]))
        pred_class = class_names[tf.argmax(pred[0][0])]
        #print(tf.argmax(pred))  
  # Plot the image and predicted class
  plt.imshow(img)
  plt.title(f"Prediction: {pred_class}")
  plt.axis(False);'''
# Out:
# 'def pred_and_plot(model, filename, class_names):\n  """\n  Imports an image located at filename, makes a prediction on it with\n  a trained model and plots the image with the predicted class as the title.\n  """\n  # Import the target image and preprocess it\n  img = load_and_prep_image(filename)\n\n  # Make a prediction\n  pred = model.predict(tf.expand_dims(img, axis=1))\n  print(len(pred[0]))\n  #cred=tf.constant(pred)\n  #cred1=cred.numpy()\n  #print(cred1)  \n  if len(pred[0])>1:\n       # pred_class_idx = int(tf.argmax(pred[0]))\n        pred_class = class_names[tf.argmax(pred[0][0])]\n        #print(tf.argmax(pred))  \n  # Plot the image and predicted class\n  plt.imshow(img)\n  plt.title(f"Prediction: {pred_class}")\n  plt.axis(False);'

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from keras.preprocessing import image
img=mpimg.imread("D:\\kaggle_prepared_dataset\\tmp\\prepared_test\\EarlyPreB\\[Malignant] early Pre-B1.png")
plt.imshow(img)
plt.axis(False)
img=cv2.resize(img,(224,224))
print(img.shape)
# swap height and width with channels
#img = tf.transpose(img, [0, 224, 224, 3])
#img=img/255
pred=np.expand_dims(img, axis=1)
#print(pred)
y_out=model.predict(pred)
print(y_out)
y_out1=np.argmax(y_out[0])
print(y_out1)
print(class_names)
print(class_names[y_out1])
# Out:
# (224, 224, 3)
# 7/7 [==============================] - 0s 9ms/step
# [[0.11050988 0.3353849  0.1321674  0.20338398 0.21855387]
#  [0.11050988 0.3353849  0.1321674  0.20338398 0.21855387]
#  [0.11050988 0.3353849  0.1321674  0.20338398 0.21855387]
#  ...
#  [0.11050988 0.3353849  0.1321674  0.20338398 0.21855387]
#  [0.11050988 0.3353849  0.1321674  0.20338398 0.21855387]
#  [0.11050988 0.3353849  0.1321674  0.20338398 0.21855387]]
# 1
# ['EarlyPreB', 'PreB', 'ProB', 'benign', 'no_cancer']
# PreB

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from keras.preprocessing import image
saved_model_dir = ''
loaded_model = tf.saved_model.load(saved_model_dir)
img=mpimg.imread("D:\\kaggle_prepared_dataset\\tmp\\prepared_test\\EarlyPreB\\[Malignant] early Pre-B1.png")
plt.imshow(img)
plt.axis(False)
img=cv2.resize(img,(224,224))
print(img.shape)
# swap height and width with channels
#img = tf.transpose(img, [0, 224, 224, 3])
#img=img/255
pred=np.expand_dims(img, axis=1)
#print(pred)
y_out=model.predict(pred)
print(y_out)
y_out1=np.argmax(y_out[0])
print(y_out1)
print(class_names)
print(class_names[y_out1])

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout
    #plt.style.use('fivethirtyeight')
    plt.show()
    
    
tr_plot(history, 0)
acc=model.evaluate(test_gen,batch_size=32, steps=None, verbose=1)[1]*100
msg='Model accuracy on test set: ' + str(acc)
print(msg, (0,255,0), (55,65,80))
# Out:
# 3/3 [==============================] - 14s 2s/step - loss: 0.2893 - accuracy: 0.9121
# Model accuracy on test set: 91.21387004852295 (0, 255, 0) (55, 65, 80)

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history["accuracy"],label="accuracy")
plt.plot(history.history["val_accuracy"],label="val_accuracy")
plt.legend(loc='lower right')

# %%
import itertools
import seaborn as sns

#Plot the Confusion matrix:
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    sns.set(style="dark")
    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\n Accuracy={:0.4f}; Misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

    
plot_confusion_matrix(cm           = np.array(matrix), 
                      normalize    = False,
                      target_names = ['EarlyPreB','PreB','ProB','benign','no cancer'],
                      title        = "Confusion Matrix")

plot_confusion_matrix(cm           = np.array(matrix), 
                      normalize    = True,
                      target_names = ['EarlyPreB','PreB','ProB','benign','no cancer'],
                      title        = "Confusion Matrix, Normalized")

# %%
from tensorflow import lite


#!ls /
#!ls /kaggle/working
# !mkdir D:\\kaggle_prepared_dataset\\working_model\\

converter = lite.TFLiteConverter.from_keras_model(model)
tfmodel = converter.convert()
#open ('./model4/model4.tflite','wb').write(tfmodel)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\Aarya\AppData\Local\Temp\tmpwmistqfp\assets
# INFO:tensorflow:Assets written to: C:\Users\Aarya\AppData\Local\Temp\tmpwmistqfp\assets

# %%
data_dir1='D:\ALL_IDB1\ALL_IDB1\im'
data_list1 = sorted(list(paths.list_images(data_dir1)))
len(data_list1)
# Out:
# 108

# %%
p=0

tic = time.perf_counter()
for img in data_list1[:]:
    i= cv2.imread(img)    
    i= cv2.resize(i,(224,224))
    lable= img.split(os.path.sep)[4]
    lable1=lable[6]
    print(lable)
    i= cv2.cvtColor(i, cv2.COLOR_BGR2RGB)
    i_lab = cv2.cvtColor(i, cv2.COLOR_RGB2LAB)        #RGB -> LAB
    l,a,b = cv2.split(i_lab)                         
    i2 = a.reshape(a.shape[0]*a.shape[1],1)
    km= KMeans(n_clusters=7, random_state=0).fit(i2)  #Clustring
    p2s= km.cluster_centers_[km.labels_]
    ic= p2s.reshape(a.shape[0],a.shape[1])
    ic = ic.astype(np.uint8)
    r,t = cv2.threshold(ic,141,255 ,cv2.THRESH_BINARY) #Binary Thresholding
    fh = ndi.binary_fill_holes(t)                      #fill holes
    m1 = morphology.remove_small_objects(fh, 200)
    m2 = morphology.remove_small_holes(m1,250)
    m2 = m2.astype(np.uint8)  
    out = cv2.bitwise_and(i, i, mask=m2)
    
    if(lable1=='1'):
        b= ('D:\\kaggle_prepared_dataset\\tmp\\prepared_test\\all\\blast\\'+lable+str(p)+'.png') 
    else:
        b= ('D:\\kaggle_prepared_dataset\\tmp\\prepared_test\\all\\no blast\\'+lable+str(p)+'.png')
        
    p+=1
    out= cv2.cvtColor(out, cv2.COLOR_RGB2BGR)
    cv2.imwrite(b,out)
    
toc2 = time.perf_counter()
print(f"2593 samples processed in { ((toc2 - tic)/60) } minutes")
# Out:
# Im001_1.jpg
# Im002_1.jpg
# Im003_1.jpg
# Im004_1.jpg
# Im005_1.jpg
# Im006_1.jpg
# Im007_1.jpg
# Im008_1.jpg
# Im009_1.jpg
# Im010_1.jpg
# Im011_1.jpg
# Im012_1.jpg
# Im013_1.jpg
# Im014_1.jpg
# Im015_1.jpg
# Im016_1.jpg
# Im017_1.jpg
# Im018_1.jpg
# Im019_1.jpg
# Im020_1.jpg
# Im021_1.jpg
# Im022_1.jpg
# Im023_1.jpg
# Im024_1.jpg
# Im025_1.jpg
# Im026_1.jpg
# Im027_1.jpg
# Im028_1.jpg
# Im029_1.jpg
# Im030_1.jpg
# Im031_1.jpg
# Im032_1.jpg
# Im033_1.jpg
# Im034_0.jpg
# Im035_0.jpg
# Im036_0.jpg
# Im037_0.jpg
# Im038_0.jpg
# Im039_0.jpg
# Im040_0.jpg
# Im041_0.jpg
# Im042_0.jpg
# Im043_0.jpg
# Im044_0.jpg
# Im045_0.jpg
# Im046_0.jpg
# Im047_0.jpg
# Im048_1.jpg
# Im049_1.jpg
# Im050_1.jpg
# Im051_1.jpg
# Im052_1.jpg
# Im053_1.jpg
# Im054_1.jpg
# Im055_1.jpg
# Im056_1.jpg
# Im057_1.jpg
# Im058_1.jpg
# Im059_1.jpg
# Im060_1.jpg
# Im061_1.jpg
# Im062_1.jpg
# Im063_1.jpg
# Im064_0.jpg
# Im065_0.jpg
# Im066_0.jpg
# Im067_0.jpg
# Im068_0.jpg
# Im069_0.jpg
# Im070_0.jpg
# Im071_0.jpg
# ...
